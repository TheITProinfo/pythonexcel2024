# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import xlwings as xw
path=r"d:\code\pythoncode\pythonexcel\day5"
os.chdir(path)


df=pd.read_excel('salestotalbymonth.xlsx')
print(df)
# print(df.columns)
# print(df.index)

sum=0
for i in range(12):
    sum+=df.loc[i,'Sales'] # 取出每一行的Sales列
print(sum)

goal=1200
rate=sum/goal # 完成率
print(rate)
# plt.bar(df['Month'],df['Sales'])
plt.bar(1,1,color='red',width=0.5)
plt.bar(1, rate, color='green', width=0.5)
plt.xlim(0,2)
plt.ylim(0, 1)
plt.text(1, rate, 'rate', ha='center', va='bottom', fontsize=10)
plt.show()
# Out:
#    Month  Sales
# 0    Jan     40
# 1    Feb     60
# 2    Mar     90
# 3    Apr    110
# 4    May    120
# 5    Jun    140
# 6    Jul    160
# 7    Aug     50
# 8    Sep     60
# 9    Oct     80
# 10   Nov     10
# 11   Dec     20
# 940
# 0.7833333333333333
# Text(1, 0.7833333333333333, 'rate')
