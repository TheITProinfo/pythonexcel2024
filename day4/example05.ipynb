# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
import xlwings as xw

path=r"d:\code\pythoncode\pythonexcel\day4"
os.chdir(path)
df=pd.read_excel("salestotal.xlsx")
figure=plt.figure() # 创建一个图形对象

x=df["Month"]
y1=df["Sales"]
y2=df["Profit"]
plt.plot(x,y2,color='r',linewidth=3,linestyle='solid',marker='*',markerfacecolor='blue',markersize=12)
plt.bar(x, y1, color='b')
plt.show()

#app=xw.App(visible=False, add_book=False) # 不显示excel应用程序
# workbook=app.books.add() # 创建一个新的excel
# worksheet=workbook.sheets[0] # 获取第一个工作表
# worksheet.pictures.add(figure, name="Bar", update=True, left=0, top=0) # 在工作表中添加图片
# workbook.save("bar.xlsx") # 保存excel文件
# workbook.close() # 关闭excel文件
# app.quit() # 退出excel应用程序

# workbook=app.books.open("salestotal.xlsx")
# worksheet=workbook.sheets[0]
# worksheet.pictures.add(figure, name="Bar", update=True, left=500, top=0)
# workbook.save()
# workbook.close()
# app.quit()
