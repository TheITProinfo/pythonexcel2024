# %%
import matplotlib.pyplot as plt
x=[25,45,69,30,82,20]
plt.pie(x)
plt.show()
plt.pie(x,labels=['a','b','c','d','e','f'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1ac3f7364d0>,
# ...
#  [Text(1.0541264944044386, 0.31435224477424845, 'a'),
#   Text(0.49768452228169663, 0.98097406504007, 'b'),
#   Text(-0.8278989529716632, 0.7242812462492897, 'c'),
#   Text(-1.0003543189594997, -0.45748359155173624, 'd'),
#   Text(0.1714480640621341, -1.0865567455634089, 'e'),
#   Text(1.0705667889147297, -0.2527582846768919, 'f')])
